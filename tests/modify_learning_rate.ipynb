# %%
import tensorflow as tf
# Out:
# 2025-07-11 22:53:18.214082: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752249198.228118 1255027 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752249198.232267 1255027 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752249198.244492 1255027 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# %cd ..
# Out:
# /media/zanub/39768EEB549F8712/projects/SELD-quadcopter

# %%
# --- These are the parameters from your get_model function ---
# 1. Define the loss functions exactly as they were in the original model.
loss_functions = ['binary_crossentropy', 'mse'] 

# 2. Define the loss weights. Based on your filename, it's likely [0.58, 50.0].
#    Replace these with the actual values from your original training script.
original_loss_weights = [1.0, 50.0] # <-- CONFIRM AND REPLACE THIS

# --- Now, let's re-compile the model ---
model_path = "./models/criset_0.120m_2class_ov1_split1_regr0_3d0_59_50LossWeights_model.keras"

# 3. Load the model architecture and weights only.
model = tf.keras.models.load_model(model_path, compile=False)

# 4. Define your new optimizer with the desired learning rate.
new_learning_rate = 0.001
new_optimizer = tf.keras.optimizers.Adam(learning_rate=new_learning_rate)

# 5. Re-compile using the information we found.
model.compile(
    optimizer=new_optimizer,
    loss=loss_functions,
    loss_weights=original_loss_weights
)

print("✅ Model re-compiled successfully with the new learning rate!")
model.summary()

model.save(model_path)
# Out:
# ✅ Model re-compiled successfully with the new learning rate!
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 16, 512,   │          0 │ -                 │
# │ (InputLayer)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 64, 512,   │      9,280 │ input_layer[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 512,   │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ...
