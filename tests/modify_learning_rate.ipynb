# %%
import tensorflow as tf
# Out:
# 2025-07-11 00:01:58.538723: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752166918.554691 1054463 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752166918.559124 1054463 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1752166918.572008 1054463 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# %cd ..
# Out:
# /media/zanub/39768EEB549F8712/projects/SELD-quadcopter/tests

# %%
model = tf.keras.models.load_model("./models/criset_0.120m_2class_ov1_split1_regr0_3d0_58_50LossWeights_model.keras")
original_weights = model.loss_weights
# Out:
# Loading with compile=True failed. Error: 'Functional' object has no attribute 'loss_weights'
#
# This can happen if your model uses custom objects (like a special loss function) that aren't defined. Try Solution 2.
